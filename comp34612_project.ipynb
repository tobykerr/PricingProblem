# %% [markdown]
# # Project Description

# %% [markdown]
# ##**Overview**
# Your task is to create a program that plays a repeated 2-person Stackelberg pricing games as the leader, under conditions of imperfect information.

# %% [markdown]
# **Notebook Structure**
#
# The notebook is structured into several sections. You can click the first icon on the top left to open the “Table of contents” and navigate through different sections.
# 1.   Project Description: This section provides an overview of the project.
# 2.   Install and Import: This section installs and imports necessary packages.
# 3.   Base Leader and Example Leader: This section contains the base leader class and an example leader implementation.
# 4.   Your Leader: In this section,
# *   First write your group number as an integer.
# *   Then implement your leader(s) based on the project requirements.
# *   Clearly document:
#       *	Which implementation approach you choose (single or multiple).
#       *	Which leader is designed to play against each follower.
# 5.   Simulation: This section provides an interface to simulate the pricing game between your selected leader and selected follower.

# %% [markdown]
# ## **Specifications**

# %% [markdown]
# **Followers’ Specifications**
#
# *   There are three different followers, named as MK1, MK2, and MK3. In addition, there are three hidden followers, MK4, MK5, and MK6. Please refer to Section [Performance of the Approach – Assessment Details Step 2](#step2) for further information.
# *   The payoff function and strategy spaces of these followers are unknown. However, historical data from 100 days of previous games between the leader and each follower is available and provided.

# %% [markdown]
# **Leader’s Specifications**
#
# Assume that the leader’s strategy (i.e., price) is $u_L$ and the follower’s strategy (i.e., price) is $u_F$. The specifics regarding the leader’s strategy and profits are as follows:
# *   **Unit cost**: $c_L=£1.00$
# *   **Strategy space**:
#       1.   When playing with MK1, MK2, MK4 and MK5, the leader’s strategy space is $U_L = [1.00, +∞)$
#       2.   When playing with MK3 and MK6, the leader’s strategy space is $U_L = [1.00, 15.00]$
# *   **Demand Model**: (i.e., price-sale relationship): $S_L(u_L, u_F)=100 - 5u_L + 3u_F$
# *   **Daily Profit**: $(u_L - c_L)S_L(u_L, u_F)$
# *   **Objective**: The leader’s objective of playing is to maximise the accumulated profit for the next 30 days.
# *   **Assumption**: For simplicity, it is assumed that the leader’s unit cost, strategy space, and the demand model remain unchanged throughout the entire period of 130 days.

# %% [markdown]
# ## **Game Rules and Playing Scenarios**

# %% [markdown]
# **Game Rules**
#
# On day $t$, the leader announces the price, $u_L (t)$, first. After learning the leader’s price, the follower will choose the responding price, $u_F (t)$. This process occurs over a period of $t=1,2,…,130$, where $t=1,2,…,100$ corresponds to the days for which historical data is available, and $t=101,102,…,130$ are the days during which the game will be played repeatedly.

# %% [markdown]
# **Game Playing Scenarios**
#
# In this setup, your program, acting as the leader, will engage in three separate games against three different competitors, identified as followers MK1, MK2, and MK3.
#
# For each of the repeated game, the leader selects his learning method to learn the follower’s reaction function based on the provided set of historical data which spans from $t=1,2,…,100$. During the next 30 days ($t=101,102,…,130$), the leader announces a price, $u_L (t)$, to the game platform daily. After the leader's price is announced, the follower will respond with the price, $u_F (t)$. Upon receiving the follower's price, $u_F (t)$, from the game platform, the leader may use this new information to refine their knowledge/ update the learned reaction function and decide his price of the next day. In the other words, the leader (i.e., your program) should be able to take the follower’s price of the previous day from the game platform for updating, and then decide and send his price of the next day to the game platform.
#
# It should be emphasised that the follower’s strategy and payoff function is subject to the changing and time varying environment. That is, the parameters in the follower’s payoff function may not be the same every day.

# %% [markdown]
# ## **Implementation Options**
# 1.	**Single Leader Approach**: You may choose to design and implement a single leader algorithm that competes against all three followers, adapting its strategy based on the opponent being faced.
# 2.	**Multiple Leaders Approach**: Alternatively, you could design and implement three distinct leaders, each tailored to play against one of the followers. This approach allows for specialised strategies to be developed for each follower type.
#
# Whichever method you choose, it's crucial to document in this notebook section [Your Leader](#your-leader) which leader(s) is designed to play against each follower. This clarity will help in understanding the design choices and strategies implemented in your program.

# %% [markdown]
# ## **Project Timeline and Support**

# %% [markdown]
# **Project Timeline**
#
# *	**Week 7 (Starting 16 March)**: Start to work on your project and project planning.
# *	**Week 11 (4 May – 8 May)**: Group presentations telling us what you have done.
# *	**Deadline (8 May at 14:00)**: Deadline to submit codes and supporting document.

# %% [markdown]
# **Support**
#
# *	**Weekly Support Sessions**: Project support sessions are scheduled every Tuesday at 9:00 am between Week 7 (17 March) and 10 (28 April). These sessions will be held at Chemistry_G.54. You are encouraged to attend if you have questions, need clarification, or seek guidance on any aspect of the project. Attendance is optional and based on your needs for support.
# *	**Email**: In addition to the weekly sessions, you are welcome to ask questions or seek support via email at any time. If you encounter any issues with installing or running the game platform, or if you have any other project-related inquiries, do not hesitate to contact the teaching assistants by email for support.

# %% [markdown]
# ## **Assessment Criteria**

# %% [markdown]
# **Assessment Criteria**
#
# The project is a significant component of your final grade, accounting for 50% of the total mark, with the remaining 50% coming from the final examination. The project mark is distributed as follows:
#
# 1.	**Content of the Approach (50% of this project mark)**:
#   * Presentation (40%): Your grade in this category is based on the presentation you give in Week 11. This includes the originality of your idea, how well it integrates knowledge from the course, and any relevant external literature or research you have incorporated.
#   * Written Materials (10%): This is based on the documentation you submit to your group journal on Blackboard. It evaluates the depth and clarity of your written explanation of the approach, including the rationale behind your strategies and methods.
# 2.	**Performance of the Approach (50% of this project mark)**:
#   * This evaluates the effectiveness of your submitted program by looking at how well it performs in the game platform, that is, the accumulated profit generated by your submitted codes.
# 3.	**Group Mark Distribution**:
#   * The overall group mark will be allocated to individual group members based on self-assessment and the demonstration of knowledge during the presentation.

# %% [markdown]
# **Presentation**
#
# During the presentation week of Semester 2, every group is scheduled to present their project to the lecturers. It is important for each group member to actively participate in speaking and answering questions. This participation allows us to evaluate each member's contributions to the project. The assessment criteria focus solely on the content of your presentation, including the activities your group undertook and the lessons learned through the project process. Presentation skills are not part of the evaluation, so the emphasis should not be on creating a polished presentation but on effectively communicating your project's substance and outcomes.

# %% [markdown]
# **Performance of the Approach – Assessment Details**
#
# *	**Step 1**: We will run your submitted codes against MK1, MK2, and MK3 and get the accumulated profit for the days $101 – 130$. These profits will be used as the performance of your submitted codes against MK1, MK2 and MK3
# *	**Step 2**<a name="step2"></a>: We have also designed 3 further followers MK4, MK5, and MK6, which are created by slightly changes of the parameters of MK1, MK2, and MK3 respectively. That is, MK1 and MK4 are very similar, MK2 and MK5 are very similar, MK3 and MK6 are very similar. No data about MK4, MK5, and MK6 is provided. That is, they are invisible followers to you. But the setting of each MK4, MK5, and MK6 is the same as the provided followers, with 100 historical data and we will run your codes to get the accumulated profit for days $101 – 130$, which will be used as the performance of your submitted codes against MK4, MK5 and MK6.
# *	**Step 3**: Based on the accumulated profits for MK1 and MK4 and compared with the best possible performances of MK1 and Mk4, your codes will get a percentage mark; Similarly you will get a percentage mark from MK2 and MK5, and then a percentage mark from MK3 and MK6. Finally your performance mark will be the average of these 3 percentage marks.
#
# **Remark**
#
# The motivation and justification for MK4, MK5, and MK6 are as follows:
# *   We have run the codes submitted by the project groups of the last year to MK4, MK5, and MK6, and noticed various issues, such as some submissions were hard coded for some parameters rather than via the learning; Some were invalid such as out of the price bounds; Some have the running errors etc.
# *   In real applications such as petrol station pricing, it is impossible to many many experiments and tests for each station, but we need a piece of software usable across a large numbers of petrol stations. The creation of MK4, MK5, and MK6 is to simulate and test such a need from a real application point of view.
# *   In the last year, many groups produced very similar performance due to the limited test cases. The creation of MK4, MK5, and MK6 will provide more testing cases and help distinguishing the performance of different approaches.
# *   As MK4, MK5, and MK6 are invisible to you, this should not add your workload for the project.

# %% [markdown]
# ## **Submission**
# Please note that
# * There is an **execution time limit of 10 minutes per run**, and all submissions will be **marked using the free version of Google Colab**.
# * **No baseline will be provided**. This is intended to encourage independent problem formulation and to promote original thinking, rather than reliance on a predefined solution approach.
#
# Before submitting, please make sure that:
# * Your implementation works within this environment.
# * Avoid using any external dependencies that might not be available.
#
# Please download this notebook for submission by clicking “File” in the top left corner, then selecting “Download” followed by “Download .ipynb”. If your notebook requires any external files to run, ensure that you submit them along with your notebook. Submission will be done through Canvas, and further details will be provided later.

# %% [markdown]
# ## **Game Platform**

# %% [markdown]
# The project will be run on Google Colab, which is a hosted Jupyter Notebook service. This is done to avoid compatibility issues across different operating systems and to provide a collaborative environment where group members can work effectively using Colab’s sharing functionality. Follow the steps below to set up and use Google Colab for your project.

# %% [markdown]
# **Setting up**
# 1.   Connect to a Runtime
# * Check if your notebook is connected to a runtime.
# * In the top-right corner, you should see a green checkmark with RAM and Disk information. If it does not show, click “Connect” to establish a connection.
#
# 2.   Upload the Project Files
# * You need to upload the zip file. Please do NOT unzip it.
# * From the left sidebar, click on the folder icon to open the file browser.
# * Upload the python files
#   * Option 1: Drag and drop the file.
#   * Option 2: Click the upload button (below “Files”) and select the file.
# * If a warning prompt will pop up, click “OK” to proceed.

# %% [markdown]
# **Using Google Colab for the Project**
# * Running Code
#   * Click on a cell and press Shift + Enter, or
#   * Click the Play button on the left side of the cell
# * Adding Cell
#   * Hover over an existing cell and click “+ Code” or “+ Text” where needed
# * Stopping a Running C→ell:
#   * From the top menu, click “Runtime” → “Interrupt execution”.
# * Restarting Runtime
#   * Click “Runtime” → “Restart session”.
#   * This will clear all variables.
# * Disconnecting and Deleting the Runtime
#   * Click “Runtime” → “Disconnect and delete session”.
#   * This will reset the Colab environment completely.
# *	Sharing with Group Members
#   *	You can share your notebook with your group members by clicking “Share” in the top-right corner.
#   *	Be careful when saving, if multiple people edit the notebook at the same time, you may overwrite each other’s work.
# *	For more functionalities, please visit [this link](https://colab.research.google.com).

# %% [markdown]
# # Install and Import

# %%
# !pip install xlsxwriter

# %%
import zipfile
import os
import random
import gc
from IPython.display import Javascript
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# Please upload *comp34612.zip* directly. Do NOT unzip it.

# %%
extract_path = "."
zip_filename = "comp34612.zip"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_filename, "r") as zip_ref:
    zip_ref.extractall(extract_path)

# %%
from engine import Engine
from gui import GUI

# %% [markdown]
# Please import the necessary packages here or use `!pip install *package_name*` if they are not already installed.

# %%
import random
import gc
import numpy as np

# %% [markdown]
# # Base Leader and Example Leader

# %% [markdown]
# ## Base Leader

# %% [markdown]
# This is the base class for all leader subclasses.

# %%
class Leader:
    _subclass_registry = {}

    def __init__(self, name, engine):
        self.name = name
        self.engine = engine

    @classmethod
    def cleanup_old_subclasses(cls):
        """
        A function to remove old subclasses before defining new ones.
        """
        existing_subclasses = list(cls.__subclasses__())

        for subclass in existing_subclasses:
            subclass_name = subclass.__name__
            if subclass_name in cls._subclass_registry:
                del cls._subclass_registry[subclass_name]
                del subclass
        gc.collect()

    @classmethod
    def update_subclass_registry(cls):
        """
        A function to update registry after cleaning up old subclasses.
        """
        cls.cleanup_old_subclasses()
        cls._subclass_registry = {subclass.__name__: subclass for subclass in cls.__subclasses__()}

    def new_price(self, date):
        """
        A function for setting the new price of each day.
        :param date: date of the day to be updated
        :return: (float) price for the day
        """
        pass

    def get_price_from_date(self, date):
        """
        A function for getting the price set on a date.
        :param date: (int) date to get the price from
        :return: a tuple (leader_price, follower_price)
        """
        return self.engine.exposed_get_price(date)


    def start_simulation(self):
        """
        A function runs at the beginning of the simulation.
        """
        pass

    def end_simulation(self):
        """
        A function runs at the beginning of the simulation.
        """
        pass

# %% [markdown]
# ## Example Leader

# %% [markdown]
# This is a simple example leader subclass.

# %%
class SimpleLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)

    def new_price(self, date: int):
        return 1.5 + random.random() * 0.1

# %% [markdown]
# <a name="your-leader"></a>
# # Your Leader

# %% [markdown]
# Please write your group number below in type int.

# %%
group_num = 34
assert isinstance(group_num, int), f"Expected an integer for group_num, but got {type(group_num).__name__}"

# %% [markdown]
# Please implement your leaders below. Please clearly document:
# *   Which implementation approach you choose (single leader approach or multiple leaders approach)
# *   State which leader(s) is designed to play against each follower.

# %% [markdown]
# UCB Leader

# %%
import numpy as np

# ============================================================
# BASE IMPROVED RLS LEADER (shared logic)
# ============================================================

class BaseImprovedRLSLeader(Leader):

    def __init__(self, name, engine,
                 min_price=1.0,
                 max_price=30.0,
                 forgetting_factor=0.99):

        super().__init__(name, engine)

        _initialise_common_state(
            self,
            min_price=min_price,
            max_price=max_price,
            grid_size=200,
        )

        self.forgetting_factor = forgetting_factor
        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)


    # --------------------------------------------------
    # Analytical optimal price
    # --------------------------------------------------
    def compute_optimal_price(self):

        a = self.a
        b = self.b
        c = self.cost

        denom = 2 * (5 - 3*b)

        if abs(denom) < 1e-6:
            return (self.min_price + self.max_price) / 2.0

        p_star = (5*c - 3*b*c + 100 + 3*a) / denom

        return p_star


    # --------------------------------------------------
    # Profit function
    # --------------------------------------------------
    def compute_profit(self, uL, uF):
        demand = 100 - 5*uL + 3*uF
        demand = max(0.0, demand)
        return (uL - self.cost) * demand


    # --------------------------------------------------
    # Start simulation
    # --------------------------------------------------
    def start_simulation(self):
        _load_initial_history(self)

        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )


    # --------------------------------------------------
    # Main pricing logic
    # --------------------------------------------------
    def new_price(self, date):

        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        # --- ingest new data ---
        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                # prediction error BEFORE update
                pred = self.a + self.b * x
                error = abs(y - pred)

                # --- adaptive forgetting ---
                if error > 5:
                    lam = self.forgetting_factor - 0.03
                else:
                    lam = min(0.999, self.forgetting_factor + 0.01)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        # --- stabilise parameters ---
        self.b = np.clip(self.b, -5, 5)
        self.a = np.clip(self.a, 0, 50)

        # --- compute optimal price ---
        price = self.compute_optimal_price()

        # ==================================================
        # FLOAT-SAFE CLAMP (critical)
        # ==================================================

        # Step 1: round first
        price = round(price, 6)

        # Step 2: strict bounds
        EPS = 1e-6
        if price >= self.max_price:
            price = self.max_price - EPS
        if price <= self.min_price:
            price = self.min_price + EPS

        # Step 3: final safety clamp
        price = max(self.min_price + EPS, min(self.max_price - EPS, price))

        return float(price)


    def end_simulation(self):
        pass


# ============================================================
# MK1 LEADER (wide range, stable follower)
# ============================================================

class MK1_FinalLeader(BaseImprovedRLSLeader):

    def __init__(self, name, engine):
        super().__init__(
            name,
            engine,
            min_price=1.0,
            max_price=30.0,
            forgetting_factor=0.99
        )


# ============================================================
# MK2 LEADER (moderate adaptation)
# ============================================================

class MK2_FinalLeader(BaseImprovedRLSLeader):

    def __init__(self, name, engine):
        super().__init__(
            name,
            engine,
            min_price=1.0,
            max_price=30.0,
            forgetting_factor=0.98
        )


# ============================================================
# MK3 LEADER (tight range, more reactive)
# ============================================================

class MK3_FinalLeader(BaseImprovedRLSLeader):

    def __init__(self, name, engine):
        super().__init__(
            name,
            engine,
            min_price=1.0,
            max_price=15.0,
            forgetting_factor=0.97
        )

# %% [markdown]
# Hill Climbing Strategy (Small changes in price, move to higher profit)

# %%
import random

class AdaptiveHillLeader(Leader):

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        # Starting price
        self.current_price = 5.0

        # Step size for hill climbing
        self.delta = 0.7

        # Exploration probability
        self.epsilon = 0.08

        # Store profits
        self.last_profit = None

        # Track best result seen
        self.best_profit = -float("inf")
        self.best_price = self.current_price

        # Price bounds
        self.min_price = 1.0
        self.max_price = 15.0


    def compute_profit(self, uL, uF):
        demand = 100 - 5*uL + 3*uF
        return (uL - 1) * demand


    def clamp(self, p):
        return max(self.min_price, min(self.max_price, p))


    def new_price(self, date: int):

        # Observe yesterday's outcome
        if date > 1:
            obs = self.get_price_from_date(date-1)

            if obs is not None:
                uL_prev, uF_prev = obs
                profit = self.compute_profit(uL_prev, uF_prev)

                # Track best seen
                if profit > self.best_profit:
                    self.best_profit = profit
                    self.best_price = uL_prev

                # adapt step size
                if self.last_profit is not None:
                    if profit > self.last_profit:
                        self.delta *= 1.05
                    else:
                        self.delta *= 0.7

                self.delta = max(0.05, min(self.delta, 2))

                self.last_profit = profit

        # Exploration
        if random.random() < self.epsilon:
            self.current_price = random.uniform(self.min_price, self.max_price)
            return self.current_price

        # Local search candidates
        up = self.clamp(self.current_price + self.delta)
        down = self.clamp(self.current_price - self.delta)

        # Choose next direction randomly between testing
        if random.random() < 0.5:
            self.current_price = up
        else:
            self.current_price = down

        # Occasionally return to best known price
        if random.random() < 0.1:
            self.current_price = self.best_price

        return self.current_price

# %% [markdown]
# Shared helper functions for following leaders

# %%
# ============================================================
# Shared helper functions
# ============================================================

def _safe_get_price(leader_obj, date):
    """
    Safely read (leader_price, follower_price) for a given date.
    Returns None if unavailable.
    """
    try:
        lp, fp = leader_obj.get_price_from_date(date)
        return float(lp), float(fp)
    except Exception:
        return None


def _load_initial_history(leader_obj):
    """
    Load the initial historical data (days 1..history_days).
    """
    if leader_obj.loaded_history:
        return

    leader_obj.X = []
    leader_obj.y = []
    leader_obj.seen_dates = set()

    for d in range(1, leader_obj.history_days + 1):
        obs = _safe_get_price(leader_obj, d)
        if obs is not None:
            lp, fp = obs
            leader_obj.X.append(lp)
            leader_obj.y.append(fp)
            leader_obj.seen_dates.add(d)

    leader_obj.loaded_history = True


def _ingest_previous_day_if_available(leader_obj, date):
    """
    At live date t, try to ingest data from day t-1 if not already added.
    """
    prev_date = date - 1
    if prev_date <= leader_obj.history_days:
        return
    if prev_date in leader_obj.seen_dates:
        return

    obs = _safe_get_price(leader_obj, prev_date)
    if obs is not None:
        lp, fp = obs
        leader_obj.X.append(lp)
        leader_obj.y.append(fp)
        leader_obj.seen_dates.add(prev_date)


def _fit_ols_params(X_vals, y_vals):
    """
    Ordinary least squares fit for:
        y = a + b x
    Returns (a, b).
    """
    n = len(X_vals)

    if n == 0:
        return 0.0, 1.0
    if n == 1:
        return float(y_vals[0]), 0.0

    X_arr = np.asarray(X_vals, dtype=float)
    y_arr = np.asarray(y_vals, dtype=float)

    A = np.column_stack([np.ones_like(X_arr), X_arr])
    coeffs, _, _, _ = np.linalg.lstsq(A, y_arr, rcond=None)

    a = float(coeffs[0])
    b = float(coeffs[1])
    return a, b


def _predict_follower_price(a, b, leader_price):
    return a + b * leader_price


def _expected_profit(cost, a, b, leader_price):
    follower_hat = _predict_follower_price(a, b, leader_price)
    demand = 100.0 - 5.0 * leader_price + 3.0 * follower_hat
    demand = max(0.0, demand)  # conservative clamp
    return (leader_price - cost) * demand


def _optimise_price(cost, a, b, min_price, max_price, grid_size):
    """
    Grid-search for the best leader price.
    """
    prices = np.linspace(min_price, max_price, grid_size)

    best_price = float(min_price)
    best_profit = -float("inf")

    for p in prices:
        prof = _expected_profit(cost, a, b, float(p))
        if prof > best_profit:
            best_profit = prof
            best_price = float(p)

    return best_price


def _rls_initial_state(P0_scale=1000.0):
    """
    Initialise recursive least squares state.
    theta = [a, b]^T
    """
    theta = np.zeros((2, 1), dtype=float)
    P = float(P0_scale) * np.eye(2, dtype=float)
    return theta, P


def _rls_update(theta, P, x, y, forgetting_factor):
    """
    One recursive least squares update for model:
        y = a + b x
    where theta = [a, b]^T
    """
    phi = np.array([[1.0], [float(x)]], dtype=float)
    y = float(y)
    lam = float(forgetting_factor)

    denom = lam + float(phi.T @ P @ phi)
    K = (P @ phi) / denom

    pred = float(phi.T @ theta)
    err = y - pred

    theta_new = theta + K * err
    P_new = (P - K @ phi.T @ P) / lam

    a = float(theta_new[0, 0])
    b = float(theta_new[1, 0])

    return theta_new, P_new, a, b


def _initialise_common_state(
    leader_obj,
    min_price,
    max_price,
    grid_size=500,
    history_days=100,
    cost=1.0,
):
    """
    Common attribute setup for all leader classes.
    """
    leader_obj.min_price = float(min_price)
    leader_obj.max_price = float(max_price)
    leader_obj.grid_size = int(grid_size)
    leader_obj.history_days = int(history_days)
    leader_obj.cost = float(cost)

    leader_obj.X = []
    leader_obj.y = []
    leader_obj.seen_dates = set()
    leader_obj.loaded_history = False

    # Current linear model: follower_price = a + b * leader_price
    leader_obj.a = 0.0
    leader_obj.b = 1.0

# %% [markdown]
# Offline OLS baseline leaders

# %%
# ============================================================
# Offline OLS baselines
# ============================================================

class MK1_OfflineOLSLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)

    def start_simulation(self):
        _load_initial_history(self)
        self.a, self.b = _fit_ols_params(self.X, self.y)

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class MK2_OfflineOLSLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)

    def start_simulation(self):
        _load_initial_history(self)
        self.a, self.b = _fit_ols_params(self.X, self.y)

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class MK3_OfflineOLSLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=15.0, grid_size=500)

    def start_simulation(self):
        _load_initial_history(self)
        self.a, self.b = _fit_ols_params(self.X, self.y)

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass

# %% [markdown]
# Online RLS leaders

# %% [markdown]
# Things worth tuning:
#
# 1. Initialisation strategy:
#
#   Right now we do:
#
#   self.theta, self.P = _rls_initial_state(self.P0_scale)
#
#   and then replay the historical 100 days through RLS in start_simulation().
#
#   That is fine, but worth comparing against:
#
#   RLS-from-scratch on the 100 days as you do now
#   OLS initialisation, then RLS online
#   possibly simple prior initialisation if OLS is awkward

# %%
# hyperparams to tune
# formatted: [MK1, MK2, MK3]
FORGETTING_FACTORS = [0.98, 0.98, 0.98]
P0_SCALES = [1000.0, 1000.0, 1000.0]
GRID_SIZES = [500, 500, 500]
MAX_PRICES = [30.0, 30.0, 15.0]

MIN_PRICES = [1.0, 1.0, 1.0] # FIXED BY BRIEF, DO NOT TUNE?

# %%
# ============================================================
# Online RLS baselines
# ============================================================

class MK1_RLSLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=MIN_PRICES[0], max_price=MAX_PRICES[0], grid_size=GRID_SIZES[0])
        self.forgetting_factor = FORGETTING_FACTORS[0]
        self.P0_scale = P0_SCALES[0]
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1
        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)
            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)
                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, self.forgetting_factor
                )

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class MK2_RLSLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=MIN_PRICES[1], max_price=MAX_PRICES[1], grid_size=GRID_SIZES[1])
        self.forgetting_factor = FORGETTING_FACTORS[1]
        self.P0_scale = P0_SCALES[1]
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1
        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)
            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)
                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, self.forgetting_factor
                )

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class MK3_RLSLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=MIN_PRICES[2], max_price=MAX_PRICES[2], grid_size=GRID_SIZES[2])
        self.forgetting_factor = FORGETTING_FACTORS[2]
        self.P0_scale = P0_SCALES[2]
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1
        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)
            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)
                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, self.forgetting_factor
                )

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass

# %% [markdown]
# Online moving-window OLS baselines

# %%
# ============================================================
# Online moving-window OLS baselines
# ============================================================

class MK1_MovingWindowLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)
        self.window_size = 30

    def _refit_window(self):
        if len(self.X) <= self.window_size:
            self.a, self.b = _fit_ols_params(self.X, self.y)
        else:
            self.a, self.b = _fit_ols_params(self.X[-self.window_size:], self.y[-self.window_size:])

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        _ingest_previous_day_if_available(self, date)
        self._refit_window()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class MK2_MovingWindowLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=100.0, grid_size=500)
        self.window_size = 50

    def _refit_window(self):
        if len(self.X) <= self.window_size:
            self.a, self.b = _fit_ols_params(self.X, self.y)
        else:
            self.a, self.b = _fit_ols_params(self.X[-self.window_size:], self.y[-self.window_size:])

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        _ingest_previous_day_if_available(self, date)
        self._refit_window()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class MK3_MovingWindowLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=15.0, grid_size=500)
        self.window_size = 50

    def _refit_window(self):
        if len(self.X) <= self.window_size:
            self.a, self.b = _fit_ols_params(self.X, self.y)
        else:
            self.a, self.b = _fit_ols_params(self.X[-self.window_size:], self.y[-self.window_size:])

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        _ingest_previous_day_if_available(self, date)
        self._refit_window()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass

# %% [markdown]
# Adaptive forgetting factor RLS

# %%
# ============================================================
# Adaptive forgetting RLS
# ============================================================

class RLSAdaptive_MK1(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=200)
        self.forgetting_factor = 0.99
        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def compute_optimal_price(self):
        a, b, c = self.a, self.b, self.cost
        denom = 2 * (5 - 3*b)
        if abs(denom) < 1e-6:
            return (self.min_price + self.max_price) / 2.0
        return (5*c - 3*b*c + 100 + 3*a) / denom

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                pred = self.a + self.b * x
                error = abs(y - pred)

                if error > 5:
                    lam = self.forgetting_factor - 0.03
                else:
                    lam = min(0.999, self.forgetting_factor + 0.01)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        self.b = np.clip(self.b, -5, 5)
        self.a = np.clip(self.a, 0, 50)

        price = self.compute_optimal_price()

        EPS = 1e-6
        price = round(price, 6)
        price = max(self.min_price + EPS, min(self.max_price - EPS, price))

        return float(price)

    def end_simulation(self):
        pass


class RLSAdaptive_MK2(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=200)
        self.forgetting_factor = 0.98
        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def compute_optimal_price(self):
        a, b, c = self.a, self.b, self.cost
        denom = 2 * (5 - 3*b)
        if abs(denom) < 1e-6:
            return (self.min_price + self.max_price) / 2.0
        return (5*c - 3*b*c + 100 + 3*a) / denom

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                pred = self.a + self.b * x
                error = abs(y - pred)

                if error > 5:
                    lam = self.forgetting_factor - 0.03
                else:
                    lam = min(0.999, self.forgetting_factor + 0.01)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        self.b = np.clip(self.b, -5, 5)
        self.a = np.clip(self.a, 0, 50)

        price = self.compute_optimal_price()

        EPS = 1e-6
        price = round(price, 6)
        price = max(self.min_price + EPS, min(self.max_price - EPS, price))

        return float(price)

    def end_simulation(self):
        pass


class RLSAdaptive_MK3(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=15.0, grid_size=200)
        self.forgetting_factor = 0.97
        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def compute_optimal_price(self):
        a, b, c = self.a, self.b, self.cost
        denom = 2 * (5 - 3*b)
        if abs(denom) < 1e-6:
            return (self.min_price + self.max_price) / 2.0
        return (5*c - 3*b*c + 100 + 3*a) / denom

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, self.forgetting_factor
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                pred = self.a + self.b * x
                error = abs(y - pred)

                if error > 5:
                    lam = self.forgetting_factor - 0.03
                else:
                    lam = min(0.999, self.forgetting_factor + 0.01)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        self.b = np.clip(self.b, -5, 5)
        self.a = np.clip(self.a, 0, 50)

        price = self.compute_optimal_price()

        EPS = 1e-6
        price = round(price, 6)
        price = max(self.min_price + EPS, min(self.max_price - EPS, price))

        return float(price)

    def end_simulation(self):
        pass

# %% [markdown]
# moving window with analytical formula derived

# %%
# ============================================================
# Moving Window OLS with analytical optimal price
# ============================================================

def _analytical_optimal_price(cost, a, b, min_price, max_price):
    """
    Closed-form maximiser for:
        profit = (uL - cost) * (100 - 5uL + 3(a + b*uL))

    where:
        predicted follower price = a + b*uL
    """
    denom = 2 * (5 - 3*b)

    if abs(denom) < 1e-6:
        price = (min_price + max_price) / 2.0
    else:
        price = (5*cost - 3*b*cost + 100 + 3*a) / denom

    EPS = 1e-6
    price = round(float(price), 6)
    price = max(min_price + EPS, min(max_price - EPS, price))

    return float(price)


class MK1_MovingWindowAnalyticalLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)
        self.window_size = 30

    def _refit_window(self):
        if len(self.X) <= self.window_size:
            self.a, self.b = _fit_ols_params(self.X, self.y)
        else:
            self.a, self.b = _fit_ols_params(
                self.X[-self.window_size:],
                self.y[-self.window_size:]
            )

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        _ingest_previous_day_if_available(self, date)
        self._refit_window()

        return _analytical_optimal_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
        )

    def end_simulation(self):
        pass


class MK2_MovingWindowAnalyticalLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)
        self.window_size = 30

    def _refit_window(self):
        if len(self.X) <= self.window_size:
            self.a, self.b = _fit_ols_params(self.X, self.y)
        else:
            self.a, self.b = _fit_ols_params(
                self.X[-self.window_size:],
                self.y[-self.window_size:]
            )

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        _ingest_previous_day_if_available(self, date)
        self._refit_window()

        return _analytical_optimal_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
        )

    def end_simulation(self):
        pass


class MK3_MovingWindowAnalyticalLeader(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=15.0, grid_size=500)
        self.window_size = 25

    def _refit_window(self):
        if len(self.X) <= self.window_size:
            self.a, self.b = _fit_ols_params(self.X, self.y)
        else:
            self.a, self.b = _fit_ols_params(
                self.X[-self.window_size:],
                self.y[-self.window_size:]
            )

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        _ingest_previous_day_if_available(self, date)
        self._refit_window()

        return _analytical_optimal_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
        )

    def end_simulation(self):
        pass

# %% [markdown]
# OLS with adaptive moving window

# %%
# ============================================================
# Improved Adaptive Moving Window OLS Leaders
# Directly inherit from Leader
# ============================================================

class ImprovedAdaptiveWindow_MK1(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)

        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)

        self.window_size = 30
        self.min_window = 8
        self.max_window = 70

        self.error_history = []
        self.error_memory = 4

        self.high_error = 4.0
        self.very_high_error = 7.0
        self.low_error = 1.5

    def _refit_window(self):
        Xw = self.X[-self.window_size:]
        yw = self.y[-self.window_size:]
        self.a, self.b = _fit_ols_params(Xw, yw)

    def _adapt_window(self, error):
        self.error_history.append(error)
        if len(self.error_history) > self.error_memory:
            self.error_history.pop(0)

        avg_error = float(np.mean(self.error_history))

        # Major regime change: shrink hard
        if error > self.very_high_error:
            self.window_size = self.min_window

        # Moderate instability: shrink window
        elif avg_error > self.high_error:
            self.window_size = max(self.min_window, self.window_size - 8)

        # Stable behaviour: slowly increase window
        elif avg_error < self.low_error:
            self.window_size = min(self.max_window, self.window_size + 4)

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs

                pred = self.a + self.b * x
                error = abs(y - pred)

                self._adapt_window(error)

                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                self._refit_window()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class ImprovedAdaptiveWindow_MK2(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)

        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=500)

        self.window_size = 50
        self.min_window = 6
        self.max_window = 60

        self.error_history = []
        self.error_memory = 4

        self.high_error = 3.5
        self.very_high_error = 6.0
        self.low_error = 1.3

    def _refit_window(self):
        Xw = self.X[-self.window_size:]
        yw = self.y[-self.window_size:]
        self.a, self.b = _fit_ols_params(Xw, yw)

    def _adapt_window(self, error):
        self.error_history.append(error)
        if len(self.error_history) > self.error_memory:
            self.error_history.pop(0)

        avg_error = float(np.mean(self.error_history))

        if error > self.very_high_error:
            self.window_size = self.min_window

        elif avg_error > self.high_error:
            self.window_size = max(self.min_window, self.window_size - 8)

        elif avg_error < self.low_error:
            self.window_size = min(self.max_window, self.window_size + 4)

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs

                pred = self.a + self.b * x
                error = abs(y - pred)

                self._adapt_window(error)

                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                self._refit_window()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass


class ImprovedAdaptiveWindow_MK3(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)

        _initialise_common_state(self, min_price=1.0, max_price=15.0, grid_size=500)

        self.window_size = 50
        self.min_window = 5
        self.max_window = 45

        self.error_history = []
        self.error_memory = 3

        self.high_error = 3.0
        self.very_high_error = 5.0
        self.low_error = 1.2

    def _refit_window(self):
        Xw = self.X[-self.window_size:]
        yw = self.y[-self.window_size:]
        self.a, self.b = _fit_ols_params(Xw, yw)

    def _adapt_window(self, error):
        self.error_history.append(error)
        if len(self.error_history) > self.error_memory:
            self.error_history.pop(0)

        avg_error = float(np.mean(self.error_history))

        if error > self.very_high_error:
            self.window_size = self.min_window

        elif avg_error > self.high_error:
            self.window_size = max(self.min_window, self.window_size - 6)

        elif avg_error < self.low_error:
            self.window_size = min(self.max_window, self.window_size + 3)

    def start_simulation(self):
        _load_initial_history(self)
        self._refit_window()

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs

                pred = self.a + self.b * x
                error = abs(y - pred)

                self._adapt_window(error)

                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                self._refit_window()

        return _optimise_price(
            cost=self.cost,
            a=self.a,
            b=self.b,
            min_price=self.min_price,
            max_price=self.max_price,
            grid_size=self.grid_size,
        )

    def end_simulation(self):
        pass

# %% [markdown]
# VFF - literature-supported adaptive RLS

# %%
# ============================================================
# Variable Forgetting Factor RLS Leaders
# Directly inherit from Leader
# ============================================================

class VFFRLS_MK1(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=200)

        self.lambda_min = 0.95
        self.lambda_max = 0.999
        self.beta = 0.08

        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def _compute_lambda(self, error):
        err_sq = float(error) ** 2
        lam = self.lambda_min + (self.lambda_max - self.lambda_min) * np.exp(-self.beta * err_sq)
        return float(np.clip(lam, self.lambda_min, self.lambda_max))

    def compute_optimal_price(self):
        a, b, c = self.a, self.b, self.cost
        denom = 2 * (5 - 3*b)

        if abs(denom) < 1e-6:
            price = (self.min_price + self.max_price) / 2.0
        else:
            price = (5*c - 3*b*c + 100 + 3*a) / denom

        EPS = 1e-6
        price = round(float(price), 6)
        return max(self.min_price + EPS, min(self.max_price - EPS, price))

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            pred = self.a + self.b * x
            error = abs(y - pred)
            lam = self._compute_lambda(error)

            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, lam
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                pred = self.a + self.b * x
                error = abs(y - pred)
                lam = self._compute_lambda(error)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        self.a = float(np.clip(self.a, 0, 50))
        self.b = float(np.clip(self.b, -5, 5))

        return float(self.compute_optimal_price())

    def end_simulation(self):
        pass


class VFFRLS_MK2(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=30.0, grid_size=200)

        self.lambda_min = 0.94
        self.lambda_max = 0.999
        self.beta = 0.10

        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def _compute_lambda(self, error):
        err_sq = float(error) ** 2
        lam = self.lambda_min + (self.lambda_max - self.lambda_min) * np.exp(-self.beta * err_sq)
        return float(np.clip(lam, self.lambda_min, self.lambda_max))

    def compute_optimal_price(self):
        a, b, c = self.a, self.b, self.cost
        denom = 2 * (5 - 3*b)

        if abs(denom) < 1e-6:
            price = (self.min_price + self.max_price) / 2.0
        else:
            price = (5*c - 3*b*c + 100 + 3*a) / denom

        EPS = 1e-6
        price = round(float(price), 6)
        return max(self.min_price + EPS, min(self.max_price - EPS, price))

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            pred = self.a + self.b * x
            error = abs(y - pred)
            lam = self._compute_lambda(error)

            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, lam
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                pred = self.a + self.b * x
                error = abs(y - pred)
                lam = self._compute_lambda(error)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        self.a = float(np.clip(self.a, 0, 50))
        self.b = float(np.clip(self.b, -5, 5))

        return float(self.compute_optimal_price())

    def end_simulation(self):
        pass


class VFFRLS_MK3(Leader):
    def __init__(self, name, engine):
        super().__init__(name, engine)
        _initialise_common_state(self, min_price=1.0, max_price=15.0, grid_size=200)

        self.lambda_min = 0.93
        self.lambda_max = 0.999
        self.beta = 0.12

        self.P0_scale = 1000.0
        self.theta, self.P = _rls_initial_state(self.P0_scale)

    def _compute_lambda(self, error):
        err_sq = float(error) ** 2
        lam = self.lambda_min + (self.lambda_max - self.lambda_min) * np.exp(-self.beta * err_sq)
        return float(np.clip(lam, self.lambda_min, self.lambda_max))

    def compute_optimal_price(self):
        a, b, c = self.a, self.b, self.cost
        denom = 2 * (5 - 3*b)

        if abs(denom) < 1e-6:
            price = (self.min_price + self.max_price) / 2.0
        else:
            price = (5*c - 3*b*c + 100 + 3*a) / denom

        EPS = 1e-6
        price = round(float(price), 6)
        return max(self.min_price + EPS, min(self.max_price - EPS, price))

    def start_simulation(self):
        _load_initial_history(self)
        self.theta, self.P = _rls_initial_state(self.P0_scale)

        for x, y in zip(self.X, self.y):
            pred = self.a + self.b * x
            error = abs(y - pred)
            lam = self._compute_lambda(error)

            self.theta, self.P, self.a, self.b = _rls_update(
                self.theta, self.P, x, y, lam
            )

    def new_price(self, date):
        if not self.loaded_history:
            self.start_simulation()

        prev_date = date - 1

        if prev_date > self.history_days and prev_date not in self.seen_dates:
            obs = _safe_get_price(self, prev_date)

            if obs is not None:
                x, y = obs
                self.X.append(x)
                self.y.append(y)
                self.seen_dates.add(prev_date)

                pred = self.a + self.b * x
                error = abs(y - pred)
                lam = self._compute_lambda(error)

                self.theta, self.P, self.a, self.b = _rls_update(
                    self.theta, self.P, x, y, lam
                )

        self.a = float(np.clip(self.a, 0, 50))
        self.b = float(np.clip(self.b, -5, 5))

        return float(self.compute_optimal_price())

    def end_simulation(self):
        pass

# %% [markdown]
# # Simulation

# %% [markdown]
# Below is the GUI interface. Please select a leader from the dropdown menu and a follower from the dropdown menu, then click “Connect.” Once the status updates to “Connected to *your_selected_leader* and *your_selected_follower*” click “Start Simulation” to begin. If you wish to save the generated data, click “Export Data.” The dataset will be saved in the “run” folder.
#
# **⚠️Please note that there is an execution time limit of 10 minutes per run.**

# %%
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'''))
engine = Engine()
app = GUI(engine, Leader, group_num)

# %% [markdown]
# ‼️**Please note that no baseline will be provided.** This is intended to encourage independent problem formulation and to promote original thinking, rather than reliance on a predefined solution approach.

# %% [markdown]
# # Marking
# For marking purposes only, please do not modify the content below.

# %%
# from marking import MarkingGUI
# marking_gui = MarkingGUI(engine, Leader, group_num)
# marking_gui.marking()

# %%
# from google.colab import files
# files.download('results.xlsx')
